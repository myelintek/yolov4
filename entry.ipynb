# %%
import os
# %matplotlib inline
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show_img(img):
    if not os.path.exists(img):
        raise Exception('%s not found.' % img)
    plt.imshow(mpimg.imread(img))

def try_detection(img):
    if not os.path.exists(img):
        raise Exception('%s not found.' % img)
    print(os.popen('./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights %s' % img).read())

# %%
img = 'data/person.jpg'
show_img(img)

# %%
try_detection(img)
# Out:
#  CUDNN_HALF=1
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32032 K-images (500 Kilo-batches_64)
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/person.jpg: Predicted in 36.166000 milli-seconds.
# dog: 99%
# person: 100%
# horse: 98%

# %%
show_img('predictions.jpg')
